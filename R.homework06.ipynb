# %% [markdown]
# <a href="https://colab.research.google.com/github/thekateee23/cs102/blob/homework06/R.homework06.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Задание №1

# %% [markdown]
# 1. Загрузите датасет music_genre.csv.
# 2. Возьмите 20 тысяч случайных строк из датасета (все остальные задания выполняйте для этих 20 тысяч строк!!!)
# 3. Проверьте, есть ли в датасете дублирующиеся строки. Если есть, удалите их.
# 4. Проверьте, есть ли а датасете строки, в которых значение в столбце artist_name – empty_field. Если есть, выведите эти строки и их количество. А затем удалите из датасета.

# %%
library(tidyverse)

# %%
data <- read.csv("music_genre.csv")

# %%
data <- sample_n(data, 20000, 42)

# %%
duplicates <- duplicated(data)
sum(duplicates) # покажет количество дублирующихся строк
# Out:
# [1] 3544

# %%
data <- distinct(data)

# %%
# Поиск строк со значением "empty_field"
empty_rows <- subset(data, artist_name == "empty_field")
empty_count <- nrow(empty_rows)

if (empty_count > 0) {
  cat("Найдено", empty_count, "строк со значением 'empty_field':\n")
  print(empty_rows)
  
  # Удаление строк со значением "empty_field"
  data <- data[!data$artist_name %in% "empty_field", ]
  cat("\nУдалены строки со значением 'empty_field'.\n")
} else {
  cat("Строк со значением 'empty_field' не найдено.\n")
}
# Out:
# Найдено 805 строк со значением 'empty_field':
#       instance_id artist_name
# 8           71011 empty_field
# 34          37622 empty_field
# 52          31008 empty_field
# 66          85864 empty_field
# 89          91200 empty_field
# 109         65505 empty_field
# 117         89248 empty_field
# 120         50535 empty_field
# 164         44473 empty_field
# 172         85946 empty_field
# 187         65872 empty_field
# 213         52752 empty_field
# 229         86977 empty_field
# 231         61823 empty_field
# 245         69497 empty_field
# 257         30340 empty_field
# 303         49173 empty_field
# 313         48883 empty_field
# 324         62818 empty_field
# 352         86232 empty_field
# 362         66664 empty_field
# 371         82224 empty_field
# 427         88441 empty_field
# 438         76684 empty_field
# 452         79929 empty_field
# 460         62948 empty_field
# 472         85181 empty_field
# 480         60192 empty_field
# 502         65284 empty_field
# 562         27414 empty_field
# 572         46832 empty_field
# 624         68998 empty_field
# 628         25896 empty_field
# 633         24758 empty_field
# 680         81123 empty_field
# 682         78373 empty_field
# 746         37364 empty_field
# 812         79357 empty_field
# 816         20110 empty_field
# 835         54275 empty_field
# 840         68254 empty_field
# 863         76323 empty_field
# 890         68043 empty_field
# 892         72052 empty_field
# 903         43356 empty_field
# 907         77769 empty_field
# 925         70343 empty_field
# 939         58569 empty_field
# 951         82891 empty_field
# 959         58626 empty_field
# 960         66792 empty_field
# 972         81751 empty_field
# 1004        52697 empty_field
# 1005        89338 empty_field
# 1042        57115 empty_field
# 1069        35733 empty_field
# 1098        22673 empty_field
# 1125        41844 empty_field
# 1138        21290 empty_field
# 1144        56656 empty_field
# 1153        80022 empty_field
# 1174        23690 empty_field
# 1178        56516 empty_field
# 1203        77154 empty_field
# 1205        39730 empty_field
# 1239        89812 empty_field
# 1261        21994 empty_field
# 1268        91405 empty_field
# 1299        85131 empty_field
# 1301        80823 empty_field
# 1303        36829 empty_field
# 1336        40213 empty_field
# 1345        67755 empty_field
# 1404        67888 empty_field
# 1410        44334 empty_field
# 1416        80003 empty_field
# 1419        63947 empty_field
# 1421        47890 empty_field
# 1460        38404 empty_field
# 1466        86728 empty_field
# 1467        22227 empty_field
# 1549        31247 empty_field
# 1556        80430 empty_field
# 1571        46007 empty_field
# 1583        68681 empty_field
# 1592        42295 empty_field
# 1646        89716 empty_field
# 1705        91655 empty_field
# 1715        83897 empty_field
# 1728        87373 empty_field
# 1745        51105 empty_field
# 1774        75695 empty_field
# 1776        46204 empty_field
# 1823        31317 empty_field
# 1845        88575 empty_field
# 1857        52151 empty_field
# 1860        30239 empty_field
# 1877        91490 empty_field
# 1884        85648 empty_field
# 1897        88696 empty_field
# 1898        74471 empty_field
# 1902        62894 empty_field
# 1903        28799 empty_field
# 1950        50586 empty_field
# 1972        56166 empty_field
# 2020        22400 empty_field
# 2022        64564 empty_field
# 2084        71625 empty_field
# 2106        59475 empty_field
# 2160        89513 empty_field
# 2175        44565 empty_field
# 2195        35211 empty_field
# 2271        41478 empty_field
# 2276        80644 empty_field
# 2326        39499 empty_field
# 2346        42467 empty_field
# 2378        52984 empty_field
# 2422        63551 empty_field
# 2441        57038 empty_field
# 2446        88754 empty_field
# 2451        45195 empty_field
# 2455        84458 empty_field
# 2482        41023 empty_field
# 2484        43865 empty_field
# 2485        87789 empty_field
# 2491        21668 empty_field
# 2532        27805 empty_field
# 2594        50068 empty_field
# 2595        27967 empty_field
# 2604        89503 empty_field
# 2609        44195 empty_field
# 2680        83200 empty_field
# 2695        43817 empty_field
# 2697        60403 empty_field
# 2707        77418 empty_field
# 2733        58801 empty_field
# 2793        71091 empty_field
# 2840        80892 empty_field
# 2898        56342 empty_field
# 2924        51454 empty_field
# 2934        39421 empty_field
# 2966        49089 empty_field
# 2988        27833 empty_field
# 2992        39944 empty_field
# 3001        72933 empty_field
# 3009        24355 empty_field
# 3037        37264 empty_field
# 3054        60346 empty_field
# 3065        82595 empty_field
# 3066        61070 empty_field
# 3082        87661 empty_field
# 3087        80158 empty_field
# 3106        58418 empty_field
# 3129        37584 empty_field
# 3132        81049 empty_field
# 3134        61550 empty_field
# 3139        70999 empty_field
# 3141        62445 empty_field
# 3156        26726 empty_field
# 3165        24611 empty_field
# 3183        77579 empty_field
# 3187        61241 empty_field
# 3240        71975 empty_field
# 3265        25293 empty_field
# 3274        84301 empty_field
# 3278        29919 empty_field
# 3279        86638 empty_field
# 3304        63928 empty_field
# 3309        38825 empty_field
# 3332        79908 empty_field
# 3368        68833 empty_field
# 3371        69047 empty_field
# 3426        75216 empty_field
# 3430        87504 empty_field
# 3434        48045 empty_field
# 3446        87780 empty_field
# 3490        87126 empty_field
# 3491        32515 empty_field
# 3508        26979 empty_field
# 3530        49781 empty_field
# 3547        65922 empty_field
# 3555        74150 empty_field
# 3587        52332 empty_field
# 3664        63888 empty_field
# 3670        50431 empty_field
# 3671        80056 empty_field
# 3719        50192 empty_field
# 3727        36723 empty_field
# 3737        63746 empty_field
# 3742        76509 empty_field
# 3750        54727 empty_field
# 3756        69479 empty_field
# 3757        58505 empty_field
# 3758        32388 empty_field
# 3767        56479 empty_field
# 3769        68360 empty_field
# 3780        43585 empty_field
# 3783        48949 empty_field
# 3785        79411 empty_field
# 3833        71609 empty_field
# 3839        34215 empty_field
# 3843        59160 empty_field
# 3867        40825 empty_field
# 3953        84217 empty_field
# 3973        52027 empty_field
# 3986        70790 empty_field
# 3991        82675 empty_field
# 4024        38675 empty_field
# 4041        32834 empty_field
# 4044        51289 empty_field
# 4056        53330 empty_field
# 4057        48031 empty_field
# 4072        24872 empty_field
# 4109        76618 empty_field
# 4117        34336 empty_field
# 4138        79280 empty_field
# 4139        44296 empty_field
# 4242        20196 empty_field
# 4244        44926 empty_field
# 4248        67243 empty_field
# 4251        54879 empty_field
# 4300        87280 empty_field
# 4330        60293 empty_field
# 4352        26729 empty_field
# 4381        85987 empty_field
# 4451        27199 empty_field
# 4454        67459 empty_field
# 4461        53664 empty_field
# 4479        26586 empty_field
# 4504        26673 empty_field
# 4526        37419 empty_field
# 4547        29931 empty_field
# 4558        26848 empty_field
# 4569        20178 empty_field
# 4590        91571 empty_field
# 4622        78113 empty_field
# 4638        41986 empty_field
# 4657        33527 empty_field
# 4675        34177 empty_field
# 4688        59526 empty_field
# 4713        35090 empty_field
# 4730        50274 empty_field
# 4735        34846 empty_field
# 4740        65908 empty_field
# 4773        57790 empty_field
# 4810        72979 empty_field
# 4818        68424 empty_field
# 4826        42679 empty_field
# 4842        32580 empty_field
# 4858        33779 empty_field
# 4860        47120 empty_field
# 4876        50292 empty_field
# 4880        28045 empty_field
# 4897        25314 empty_field
# 4903        33459 empty_field
# 4925        22118 empty_field
# 4929        64351 empty_field
# 4970        27698 empty_field
# 4978        87536 empty_field
# 4986        49320 empty_field
# 4993        36831 empty_field
# 5005        89752 empty_field
# 5036        54021 empty_field
# 5043        75099 empty_field
# 5052        59511 empty_field
# 5064        44636 empty_field
# 5065        86011 empty_field
# 5090        37879 empty_field
# 5115        67262 empty_field
# 5140        90804 empty_field
# 5167        60895 empty_field
# 5179        74312 empty_field
# 5222        49868 empty_field
# 5244        42177 empty_field
# 5272        26793 empty_field
# 5273        64036 empty_field
# 5295        83267 empty_field
# 5298        46218 empty_field
# 5321        54634 empty_field
# 5349        48312 empty_field
# 5353        33773 empty_field
# 5365        32224 empty_field
# 5392        27131 empty_field
# 5403        70988 empty_field
# 5431        35434 empty_field
# 5491        37009 empty_field
# 5494        27980 empty_field
# 5500        51320 empty_field
# 5503        78616 empty_field
# 5507        33426 empty_field
# 5539        41180 empty_field
# 5548        41332 empty_field
# 5577        81546 empty_field
# 5579        89073 empty_field
# 5583        20941 empty_field
# 5599        47104 empty_field
# 5636        32069 empty_field
# 5640        24596 empty_field
# 5655        84154 empty_field
# 5664        59673 empty_field
# 5673        39630 empty_field
# 5704        87163 empty_field
# 5746        33008 empty_field
# 5747        90142 empty_field
# 5770        52153 empty_field
# 5775        86244 empty_field
# 5777        62426 empty_field
# 5839        83633 empty_field
# 5872        43763 empty_field
# 5873        58816 empty_field
# 5887        25861 empty_field
# 5919        35173 empty_field
# 5932        88637 empty_field
# 6005        72211 empty_field
# 6014        56794 empty_field
# 6016        38732 empty_field
# 6036        33932 empty_field
# 6040        21424 empty_field
# 6067        80996 empty_field
# 6135        37326 empty_field
# 6139        38193 empty_field
# 6180        23397 empty_field
# 6202        48459 empty_field
# 6242        87878 empty_field
# 6246        75294 empty_field
# 6310        85877 empty_field
# 6385        40570 empty_field
# 6387        80552 empty_field
# 6394        85922 empty_field
# 6399        21175 empty_field
# 6409        77422 empty_field
# 6440        40629 empty_field
# 6499        21707 empty_field
# 6563        38090 empty_field
# 6585        64313 empty_field
# 6629        37277 empty_field
# 6648        66267 empty_field
# 6739        40367 empty_field
# 6740        91210 empty_field
# 6767        43757 empty_field
# 6777        46086 empty_field
# 6809        61768 empty_field
# 6813        85214 empty_field
# 6822        38108 empty_field
# 6835        91320 empty_field
# 6836        67759 empty_field
# 6859        41042 empty_field
# 6860        69543 empty_field
# 6891        90586 empty_field
# 6962        73638 empty_field
# 7060        46833 empty_field
# 7079        58446 empty_field
# 7086        69167 empty_field
# 7096        53295 empty_field
# 7097        60043 empty_field
# 7098        43136 empty_field
# 7115        47260 empty_field
# 7117        68747 empty_field
# 7129        54927 empty_field
# 7138        45940 empty_field
# 7141        74314 empty_field
# 7145        55991 empty_field
# 7169        35607 empty_field
# 7220        44428 empty_field
# 7223        44013 empty_field
# 7224        46827 empty_field
# 7310        36010 empty_field
# 7407        56324 empty_field
# 7409        74934 empty_field
# 7410        77926 empty_field
# 7429        68222 empty_field
# 7431        58389 empty_field
# 7458        59149 empty_field
# 7469        56050 empty_field
# 7471        30159 empty_field
# 7474        79201 empty_field
# 7494        76317 empty_field
# 7539        87085 empty_field
# 7556        47112 empty_field
# 7601        41529 empty_field
# 7612        29916 empty_field
# 7641        38486 empty_field
# 7678        86615 empty_field
# 7691        53978 empty_field
# 7735        46911 empty_field
# 7761        73359 empty_field
# 7766        77787 empty_field
# 7792        26311 empty_field
# 7808        36478 empty_field
# 7896        36397 empty_field
# 7907        27780 empty_field
# 7925        58898 empty_field
# 7954        83715 empty_field
# 7960        21153 empty_field
# 7968        91547 empty_field
# 8006        23215 empty_field
# 8012        63413 empty_field
# 8042        22051 empty_field
# 8058        42000 empty_field
# 8071        91306 empty_field
# 8081        46739 empty_field
# 8112        66240 empty_field
# 8117        70330 empty_field
# 8137        57110 empty_field
# 8166        61175 empty_field
# 8172        34248 empty_field
# 8194        42032 empty_field
# 8203        63826 empty_field
# 8255        78230 empty_field
# 8258        54820 empty_field
# 8285        28367 empty_field
# 8306        22346 empty_field
# 8310        30823 empty_field
# 8322        37542 empty_field
# 8353        71828 empty_field
# 8355        31133 empty_field
# 8385        81053 empty_field
# 8394        32432 empty_field
# 8425        53277 empty_field
# 8446        55583 empty_field
# 8459        85208 empty_field
# 8548        57946 empty_field
# 8564        72693 empty_field
# 8573        44069 empty_field
# 8584        68510 empty_field
# 8589        30502 empty_field
# 8590        61605 empty_field
# 8604        81681 empty_field
# 8636        28447 empty_field
# 8642        32210 empty_field
# 8675        55748 empty_field
# 8693        57930 empty_field
# 8735        79144 empty_field
# 8760        62155 empty_field
# 8769        91721 empty_field
# 8810        85038 empty_field
# 8821        47479 empty_field
# 8860        71943 empty_field
# 8862        46453 empty_field
# 8864        30523 empty_field
# 8900        66517 empty_field
# 8958        32824 empty_field
# 8986        69757 empty_field
# 9003        77523 empty_field
# 9006        87918 empty_field
# 9023        78922 empty_field
# 9027        87807 empty_field
# 9046        68389 empty_field
# 9058        59445 empty_field
# 9079        56423 empty_field
# 9134        65032 empty_field
# 9155        43510 empty_field
# 9159        90863 empty_field
# 9166        84117 empty_field
# 9171        73273 empty_field
# 9207        75072 empty_field
# 9213        49325 empty_field
# 9216        33790 empty_field
# 9219        83958 empty_field
# 9265        42358 empty_field
# 9304        89987 empty_field
# 9311        32625 empty_field
# 9356        78584 empty_field
# 9365        29203 empty_field
# 9369        53995 empty_field
# 9408        55198 empty_field
# 9419        38507 empty_field
# 9432        71519 empty_field
# 9444        73596 empty_field
# 9447        46733 empty_field
# 9478        65399 empty_field
# 9524        65556 empty_field
# 9532        62907 empty_field
# 9560        67120 empty_field
# 9563        51055 empty_field
# 9586        84993 empty_field
# 9590        36047 empty_field
# 9597        40146 empty_field
# 9604        45780 empty_field
# 9628        51109 empty_field
# 9639        35396 empty_field
# 9647        56544 empty_field
# 9649        47657 empty_field
# 9653        42840 empty_field
# 9669        53019 empty_field
# 9674        72921 empty_field
# 9686        33368 empty_field
# 9704        73524 empty_field
# 9718        79809 empty_field
# 9725        70144 empty_field
# 9735        41731 empty_field
# 9745        41500 empty_field
# 9781        75723 empty_field
# 9785        89776 empty_field
# 9794        89669 empty_field
# 9882        53143 empty_field
# 9905        24313 empty_field
# 9939        37755 empty_field
# 9942        20962 empty_field
# 9974        55551 empty_field
# 9982        51712 empty_field
# 10021       74964 empty_field
# 10024       34502 empty_field
# 10044       72554 empty_field
# 10066       20836 empty_field
# 10096       73439 empty_field
# 10133       45406 empty_field
# 10155       50605 empty_field
# 10200       81671 empty_field
# 10201       69434 empty_field
# 10210       64628 empty_field
# 10322       45842 empty_field
# 10335       34606 empty_field
# 10430       20487 empty_field
# 10504       62544 empty_field
# 10532       65171 empty_field
# 10553       24551 empty_field
# 10565       48234 empty_field
# 10576       27788 empty_field
# 10600       86725 empty_field
# 10609       65666 empty_field
# 10618       37308 empty_field
# 10631       25091 empty_field
# 10646       72295 empty_field
# 10652       83265 empty_field
# 10667       50118 empty_field
# 10673       59625 empty_field
# 10681       42913 empty_field
# 10743       90399 empty_field
# 10774       90510 empty_field
# 10791       29937 empty_field
# 10800       82354 empty_field
# 10823       77181 empty_field
# 10856       72002 empty_field
# 13280       35783 empty_field
# 13290       20030 empty_field
# 13298       60324 empty_field
# 13312       89276 empty_field
# 13318       30335 empty_field
# 13323       59826 empty_field
# 13364       61003 empty_field
# 13370       74938 empty_field
# 13373       71184 empty_field
# 13381       82370 empty_field
# 13382       70342 empty_field
# 13383       61479 empty_field
# 13424       47018 empty_field
# 13439       29541 empty_field
# 13455       21892 empty_field
# 13486       38352 empty_field
# 13487       51488 empty_field
# 13496       56032 empty_field
# 13507       63647 empty_field
# 13520       32618 empty_field
# 13521       27721 empty_field
# 13523       87481 empty_field
# 13552       55147 empty_field
# 13553       35797 empty_field
# 13581       71263 empty_field
# 13632       77913 empty_field
# 13664       54068 empty_field
# 13707       41626 empty_field
# 13728       52161 empty_field
# 13768       20087 empty_field
# 13772       61595 empty_field
# 13801       62153 empty_field
# 13804       75345 empty_field
# 13814       56883 empty_field
# 13827       26442 empty_field
# 13829       49647 empty_field
# 13868       71041 empty_field
# 13880       91451 empty_field
# 13907       69931 empty_field
# 13909       35468 empty_field
# 13914       87019 empty_field
# 13929       35236 empty_field
# 13933       63393 empty_field
# 13937       21012 empty_field
# 14008       76937 empty_field
# 14018       49686 empty_field
# 14026       37607 empty_field
# 14032       58848 empty_field
# 14045       24844 empty_field
# 14071       56006 empty_field
# 14081       34830 empty_field
# 14102       87828 empty_field
# 14120       83509 empty_field
# 14126       49164 empty_field
# 14131       56654 empty_field
# 14193       38534 empty_field
# 14233       47346 empty_field
# 14253       73097 empty_field
# 14258       45196 empty_field
# 14296       82359 empty_field
# 14330       37288 empty_field
# 14349       55912 empty_field
# 14379       54612 empty_field
# 14396       22011 empty_field
# 14409       44738 empty_field
# 14410       38894 empty_field
# 14440       49022 empty_field
# 14462       77345 empty_field
# 14493       26225 empty_field
# 14505       53872 empty_field
# 14550       49178 empty_field
# 14555       81108 empty_field
# 14565       35472 empty_field
# 14587       54197 empty_field
# 14595       72364 empty_field
# 14671       61335 empty_field
# 14677       28000 empty_field
# 14678       81744 empty_field
# 14709       41491 empty_field
# 14722       31930 empty_field
# 14727       79596 empty_field
# 14756       58104 empty_field
# 14771       60358 empty_field
# 14801       42512 empty_field
# 14802       40401 empty_field
# 14807       77079 empty_field
# 14836       27135 empty_field
# 14869       73935 empty_field
# 14881       63631 empty_field
# 14906       74733 empty_field
# 14917       55309 empty_field
# 14918       69342 empty_field
# 14994       39635 empty_field
# 15052       34853 empty_field
# 15151       82489 empty_field
# 15219       69318 empty_field
# 15223       84474 empty_field
# 15302       68540 empty_field
# 15319       55746 empty_field
# 15337       21759 empty_field
# 15338       57751 empty_field
# 15406       86765 empty_field
# 15450       82867 empty_field
# 15477       43405 empty_field
# 15489       27366 empty_field
# 15496       21472 empty_field
# 15500       27380 empty_field
# 15512       59003 empty_field
# 15542       41162 empty_field
# 15560       70580 empty_field
# 15582       22863 empty_field
# 15590       28780 empty_field
# 15661       43067 empty_field
# 15673       87736 empty_field
# 15688       42969 empty_field
# 15703       69156 empty_field
# 15711       83945 empty_field
# 15713       51522 empty_field
# 15746       47514 empty_field
# 15771       50537 empty_field
# 15787       25248 empty_field
# 15805       50025 empty_field
# 15829       33507 empty_field
# 15845       89121 empty_field
# 15860       39170 empty_field
# 15882       55941 empty_field
# 15900       87649 empty_field
# 15915       67776 empty_field
# 15916       42826 empty_field
# 15949       46417 empty_field
# 15956       59434 empty_field
# 15961       77945 empty_field
# 15965       66057 empty_field
# 15976       39414 empty_field
# 15977       60690 empty_field
# 15994       60330 empty_field
# 16007       60187 empty_field
# 16009       40941 empty_field
# 16034       60132 empty_field
# 16040       78453 empty_field
# 16052       23491 empty_field
# 16077       51201 empty_field
# 16095       69899 empty_field
# 16096       79512 empty_field
# 16106       43601 empty_field
# 16127       45137 empty_field
# 16150       40524 empty_field
# 16206       33804 empty_field
# 16235       89067 empty_field
# 16307       37452 empty_field
# 16314       80196 empty_field
# 16324       46078 empty_field
# 16362       59876 empty_field
# 16377       22970 empty_field
# 16427       85985 empty_field
#                                                                                                                                                track_name
# 8                                                                                                                                      Hedgehog's Dilemma
# 34                                                                                                                          Good Vibes (feat. Lutan Fyah)
# 52                                                                                                                                                  youth
# 66                                                                                                           Les Cinq Doights (1921): Moderato - Produced
# 89                                                                                                                                                 Swervo
# 109                                                                                                                                    A Flower Named You
# 117                                                                                                                                                  O.D.
# 120                                                                                                                                   Monkey In Your Soul
# 164                                                                                                                                        Natsu No Ringo
# 172                                                                                                                                               JOURNEY
# 187                                                                                                                                     Stand By Your Man
# 213                                                                                                                                                  MTRD
# 229                                                                                                                                      The Perfect Drug
# 231                                                                                                                                 Swingin' At The Savoy
# 245                                                                                                                                            Battle Cry
# 257                                                                                           The Sleeping Beauty, Op.66, TH.13 / Prologue: 3. Pas de six
# 303                                                                                                                                             Hoe Cakes
# 313                                                                                                                                      Vor í Vaglaskógi
# 324                                                                                                                                              The Blow
# 352                                                                                                                                        DRIVE ME CRAZY
# 362                                                                                                                                      Hashire! Bicycle
# 371                                                                                                                        Ballade No.1 In G Minor, Op.23
# 427                                                                                                                                 Take Me as You Please
# 438                                                                                                                                          The Rio Dawn
# 452                                                                                                                                             The Motto
# 460                                                                                                                                            Bush Party
# 472                                                                                                                                                 Bloom
# 480                                                                                                                                               Magenta
# 502                                                                                                                                                  STFU
# 562                                                                                                                                              Hold Her
# 572                                                                                                                                               Hey You
# 624                                                                                                                                      Coming Back Down
# 628                                                                                                                                      Moving in Stereo
# 633                                                                                                                                                  Vibe
# 680                                                                           Finish Line / Drown (feat. T-Pain, Kirk Franklin, Eryn Allen Kane & Noname)
# 682                                                                                                                                            Conception
# 746                                                                                                                                              platinum
# 812                                                                             The Nutcracker, Op.71 : No. 10 The Magic Castle on the Mountain of Sweets
# 816                                                                                                                                           Tongue Tied
# 835                                                                                                                                    Save Me - Acoustic
# 840                                                                                                                                                 Unity
# 863                                                                                                                                           Night Drive
# 890                                                                                                                                        Saturday Night
# 892                                                                                                                                                  Wait
# 4109   0.1780       Anime
# 4117   0.1930 Alternative
# 4138   0.4060       Blues
# 4139   0.0668   Classical
# 4242   0.1460       Anime
# 4244   0.3960        Rock
# 4248   0.9350        Jazz
# 4251   0.7310         Rap
# 4300   0.6920 Alternative
# 4330   0.6110     Hip-Hop
# 4352   0.6830        Rock
# 4381   0.5160         Rap
# 4451   0.4430         Rap
# 4454   0.5660     Hip-Hop
# 4461   0.5730        Jazz
# 4479   0.8480     Country
# 4504   0.1880       Blues
# 4526   0.9630        Rock
# 4547   0.7900        Jazz
# 4558   0.7670       Blues
# 4569   0.3510     Hip-Hop
# 4590   0.5190 Alternative
# 4622   0.2600  Electronic
# 4638   0.5870     Country
# 4657   0.4040 Alternative
# 4675   0.7290        Jazz
# 4688   0.0783        Jazz
# 4713   0.3570     Hip-Hop
# 4730   0.5040     Hip-Hop
# 4735   0.3880       Blues
# 4740   0.7960 Alternative
# 4773   0.8250        Jazz
# 4810   0.6850        Jazz
# 4818   0.5100       Blues
# 4826   0.2220       Anime
# 4842   0.9600        Rock
# 4858   0.8800        Jazz
# 4860   0.3280   Classical
# 4876   0.6380         Rap
# 4880   0.4130     Hip-Hop
# 4897   0.2300   Classical
# 4903   0.5810       Blues
# 4925   0.4040        Jazz
# 4929   0.3700        Rock
# 4970   0.1220        Jazz
# 4978   0.1750       Anime
# 4986   0.3150       Blues
# 4993   0.2130  Electronic
# 5005   0.3050        Jazz
# 5036   0.2310 Alternative
# 5043   0.3830        Jazz
# 5052   0.3390         Rap
# 5064   0.5470        Rock
# 5065   0.4220       Blues
# 5090   0.5290        Jazz
# 5115   0.5080     Hip-Hop
# 5140   0.7570        Jazz
# 5167   0.9780 Alternative
# 5179   0.0643       Anime
# 5222   0.5340        Rock
# 5244   0.9370       Blues
# 5272   0.3850   Classical
# 5273   0.5760        Jazz
# 5295   0.7380        Rock
# 5298   0.1260   Classical
# 5321   0.2640     Country
# 5349   0.2050  Electronic
# 5353   0.0930        Jazz
# 5365   0.0621 Alternative
# 5392   0.2420       Anime
# 5403   0.1530   Classical
# 5431   0.5150        Rock
# 5491   0.7330  Electronic
# 5494   0.4100     Hip-Hop
# 5500   0.3080 Alternative
# 5503   0.1860   Classical
# 5507   0.2310 Alternative
# 5539   0.4390     Country
# 5548   0.2790        Rock
# 5577   0.1270   Classical
# 5579   0.1630         Rap
# 5583   0.4680     Country
# 5599   0.2960 Alternative
# 5636   0.9090       Blues
# 5640   0.3480     Hip-Hop
# 5655   0.3420 Alternative
# 5664   0.5500       Blues
# 5673   0.7200       Blues
# 5704   0.0504   Classical
# 5746   0.5080       Anime
# 5747   0.2820  Electronic
# 5770   0.2820         Rap
# 5775   0.3830         Rap
# 5777   0.3980  Electronic
# 5839   0.8620        Jazz
# 5872   0.6270 Alternative
# 5873   0.5370 Alternative
# 5887   0.7100 Alternative
# 5919   0.3230 Alternative
# 5932   0.9730 Alternative
# 6005   0.6430  Electronic
# 6014   0.1530     Country
# 6016   0.8330       Blues
# 6036   0.2900   Classical
# 6040   0.3190       Anime
# 6067   0.3000        Rock
# 6135   0.0874     Hip-Hop
# 6139   0.1700        Jazz
# 6180   0.4930       Anime
# 6202   0.0370   Classical
# 6242   0.3230         Rap
# 6246   0.5840        Rock
# 6310   0.6480         Rap
# 6385   0.7100         Rap
# 6387   0.0380   Classical
# 6394   0.2750        Jazz
# 6399   0.7160 Alternative
# 6409   0.2660  Electronic
# 6440   0.2780 Alternative
# 6499   0.2830   Classical
# 6563   0.0763       Anime
# 6585   0.3740       Blues
# 6629   0.2970         Rap
# 6648   0.6260       Blues
# 6739   0.7090       Anime
# 6740   0.4050        Rock
# 6767   0.2120     Country
# 6777   0.6960     Country
# 6809   0.8080  Electronic
# 6813   0.8070 Alternative
# 6822   0.0581   Classical
# 6835   0.1500     Country
# 6836   0.4830  Electronic
# 6859   0.2950     Hip-Hop
# 6860   0.3040         Rap
# 6891   0.5300  Electronic
# 6962   0.8640     Country
# 7060   0.8240        Jazz
# 7079   0.6410   Classical
# 7086   0.1860   Classical
# 7096   0.1180 Alternative
# 7097   0.5960        Jazz
# 7098   0.3620       Anime
# 7115   0.4790       Anime
# 7117   0.2880         Rap
# 7129   0.4380       Anime
# 7138   0.0741        Rock
# 7141   0.0603   Classical
# 7145   0.2250       Anime
# 7169   0.5560     Country
# 7220   0.6030        Rock
# 7223   0.5270 Alternative
# 7224   0.0940     Hip-Hop
# 7310   0.9660        Rock
# 7407   0.2530        Rock
# 7409   0.1120   Classical
# 7410   0.3460     Country
# 7429   0.6970         Rap
# 7431   0.9530     Country
# 7458   0.3870         Rap
# 7469   0.2730         Rap
# 7471   0.8440        Rock
# 7474   0.1130       Blues
# 7494   0.4730     Country
# 7539   0.4940        Rock
# 7556   0.1500   Classical
# 7601   0.4940     Hip-Hop
# 7612   0.2040     Country
# 7641   0.6220     Country
# 7678   0.7660     Country
# 7691   0.5610         Rap
# 7735   0.6960         Rap
# 7761   0.5030     Country
# 7766   0.2290        Rock
# 7792   0.6130   Classical
# 7808   0.0754 Alternative
# 7896   0.1790     Hip-Hop
# 7907   0.5210     Country
# 7925   0.3990       Blues
# 7954   0.8170       Blues
# 7960   0.4930       Anime
# 7968   0.0556     Country
# 8006   0.3620  Electronic
# 8012   0.6640   Classical
# 8042   0.8700       Anime
# 8058   0.6490     Country
# 8071   0.1730   Classical
# 8081   0.2910     Country
# 8112   0.7330        Rock
# 8117   0.5390  Electronic
# 8137   0.5840         Rap
# 8166   0.6630     Country
# 8172   0.7420         Rap
# 8194   0.2750         Rap
# 8203   0.1530        Jazz
# 8255   0.7880        Rock
# 8258   0.3850       Blues
# 8285   0.0731     Hip-Hop
# 8306   0.7130   Classical
# 8310   0.1140  Electronic
# 8322   0.5020         Rap
# 8353   0.8560         Rap
# 8355   0.5270     Country
# 8385   0.6010        Jazz
# 8394   0.1890         Rap
# 8425   0.3580        Jazz
# 8446   0.7580     Country
# 8459   0.2470   Classical
# 8548   0.6070        Rock
# 8564   0.0378   Classical
# 8573   0.7060 Alternative
# 8584   0.7010   Classical
# 8589   0.2080        Jazz
# 8590   0.1390         Rap
# 8604   0.0362   Classical
# 8636   0.1000  Electronic
# 8642   0.1070   Classical
# 8675   0.3300        Jazz
# 8693   0.7320     Hip-Hop
# 8735   0.4500         Rap
# 8760   0.2330     Country
# 8769   0.4430     Hip-Hop
# 8810   0.4470        Jazz
# 8821   0.2880 Alternative
# 8860   0.4270 Alternative
# 8862   0.6530        Rock
# 8864   0.4860     Hip-Hop
# 8900   0.7160       Blues
# 8958   0.5470     Hip-Hop
# 8986   0.1840     Hip-Hop
# 9003   0.5340     Hip-Hop
# 9006   0.0467   Classical
# 9023   0.5610 Alternative
# 9027   0.2960       Blues
# 9046   0.7790        Rock
# 9058   0.2330       Anime
# 9079   0.2850         Rap
# 9134   0.6400         Rap
# 9155   0.0768   Classical
# 9159   0.3870       Blues
# 9166   0.4720 Alternative
# 9171   0.9630       Blues
# 9207   0.7190       Blues
# 9213   0.4100 Alternative
# 9216   0.9630       Blues
# 9219   0.7810       Blues
# 9265   0.2710   Classical
# 9304   0.6520 Alternative
# 9311   0.4850       Anime
# 9356   0.0338       Anime
# 9365   0.4490   Classical
# 9369   0.1750       Anime
# 9408   0.5610     Hip-Hop
# 9419   0.0648       Anime
# 9432   0.4040     Hip-Hop
# 9444   0.6240       Blues
# 9447   0.2240       Blues
# 9478   0.6700        Rock
# 9524   0.9160       Anime
# 9532   0.9440     Hip-Hop
# 9560   0.3220         Rap
# 9563   0.1160  Electronic
# 9586   0.3950         Rap
# 9590   0.4180  Electronic
# 9597   0.3900        Rock
# 9604   0.3580     Country
# 9628   0.5400     Country
# 9639   0.4200     Country
# 9647   0.4950         Rap
# 9649   0.2840         Rap
# 9653   0.2880  Electronic
# 9669   0.5340  Electronic
# 9674   0.4900     Hip-Hop
# 9686   0.4950     Country
# 9704   0.5730        Rock
# 9718   0.5460        Rock
# 9725   0.5370 Alternative
# 9735   0.4980        Rock
# 9745   0.4100       Blues
# 9781   0.2180  Electronic
# 9785   0.7150     Hip-Hop
# 9794   0.8310        Rock
# 9882   0.3380       Blues
# 9905   0.5190     Country
# 9939   0.8450  Electronic
# 9942   0.2390        Jazz
# 9974   0.3940     Country
# 9982   0.6600   Classical
# 10021  0.9140       Blues
# 10024  0.5180   Classical
# 10044  0.3560       Blues
# 10066  0.2360   Classical
# 10096  0.0368   Classical
# 10133  0.7800 Alternative
# 10155  0.1780  Electronic
# 10200  0.5790        Jazz
# 10201  0.6290     Hip-Hop
# 10210  0.5540        Rock
# 10322  0.7600     Country
# 10335  0.5960         Rap
# 10430  0.9380   Classical
# 10504  0.3500 Alternative
# 10532  0.2190     Country
# 10553  0.6200         Rap
# 10565  0.1610  Electronic
# 10576  0.0366       Anime
# 10600  0.8780     Country
# 10609  0.2110  Electronic
# 10618  0.4750         Rap
# 10631  0.8940       Blues
# 10646  0.0841   Classical
# 14722  0.3510     Country
# 14727  0.1830       Anime
# 14756  0.4960     Country
# 14771  0.8090         Rap
# 14801  0.8930         Rap
# 14802  0.4640     Hip-Hop
# 14807  0.4540        Rock
# 14836  0.1900   Classical
# 14869  0.6500         Rap
# 14881  0.7160       Anime
# 14906  0.5060  Electronic
# 14917  0.3700   Classical
# 14918  0.2440         Rap
# 14994  0.5860     Country
# 15052  0.6550         Rap
# 15151  0.5570       Anime
# 15219  0.2300       Blues
# 15223  0.0574   Classical
# 15302  0.2120     Country
# 15319  0.5190 Alternative
# 15337  0.7150     Hip-Hop
# 15338  0.0940       Anime
# 15406  0.2790 Alternative
# 15450  0.9430        Rock
# 15477  0.5790     Country
# 15489  0.0346   Classical
# 15496  0.1960         Rap
# 15500  0.6480        Jazz
# 15512  0.0349  Electronic
# 15542  0.2870        Jazz
# 15560  0.3580  Electronic
# 15582  0.3950  Electronic
# 15590  0.6410       Blues
# 15661  0.8870     Hip-Hop
# 15673  0.4580       Anime
# 15688  0.0392  Electronic
# 15703  0.1290   Classical
# 15711  0.4270         Rap
# 15713  0.4520        Rock
# 15746  0.2000        Jazz
# 15771  0.1790 Alternative
# 15787  0.1510   Classical
# 15805  0.2480 Alternative
# 15829  0.6700       Blues
# 15845  0.6030         Rap
# 15860  0.2970         Rap
# 15882  0.2000     Country
# 15900  0.5210       Anime
# 15915  0.0449   Classical
# 15916  0.9640       Blues
# 15949  0.7460        Rock
# 15956  0.5120       Blues
# 15961  0.3570       Blues
# 15965  0.2790       Anime
# 15976  0.2270         Rap
# 15977  0.0303   Classical
# 15994  0.2610       Blues
# 16007  0.9020        Rock
# 16009  0.2030       Blues
# 16034  0.1890        Jazz
# 16040  0.2390       Anime
# 16052  0.6250         Rap
# 16077  0.2520   Classical
# 16095  0.4670 Alternative
# 16096  0.6350     Hip-Hop
# 16106  0.9430        Jazz
# 16127  0.0426   Classical
# 16150  0.1410     Hip-Hop
# 16206  0.6570       Anime
# 16235  0.8210        Jazz
# 16307  0.3240     Country
# 16314  0.3570        Rock
# 16324  0.8230       Anime
# 16362  0.7750        Jazz
# 16377  0.5470 Alternative
# 16427  0.8970  Electronic
#
# Удалены строки со значением 'empty_field'.

# %%
data <- unique(data)

# %% [markdown]
# Задание №2 вторая часть задания не сделана

# %% [markdown]
# 1. Выведите долю каждого жанра в датасете.
# 2. Покажите на горизонтальной столбиковой диаграмме распределение количества треков по жанрам. Выделите контрастным цветом жанр, в котором больше всего песен.
# 3. Найдите самый танцевальный жанр. У самого танцевального жанра среднее значение показателя danceability должно быть наивысшим.
# 4. Для каждого жанра определите, какая тональность в нем преобладает – количество треков какой тональность больше (минор или мажор).

# %%
genre_count <- data %>%
  count(music_genre) %>%
  mutate(share = n / sum(n)) %>%
  arrange(desc(share))

genre_count
# Out:
#    music_genre n    share
# 1  Electronic  1627 0.10395502
# 2  Rap         1601 0.10229378
# 3  Blues       1594 0.10184653
# 4  Hip-Hop     1581 0.10101591
# 5  Country     1564 0.09992972
# 6  Jazz        1562 0.09980193
# 7  Alternative 1547 0.09884352
# 8  Anime       1533 0.09794901
# 9  Rock        1528 0.09762954
# 10 Classical   1514 0.09673503

# %%
library(ggplot2)

genre_count <- data %>%
  group_by(music_genre) %>%
  summarize(track_count = n()) %>%
  arrange(desc(track_count))

ggplot(genre_count, aes(x = music_genre, y = track_count)) +
  geom_col(fill = ifelse(genre_count$music_genre[1] == genre_count$music_genre, "red", "grey")) + 
  labs(title = "Распределение количества треков по жанрам",
       x = "Жанры",
       y = "Количество треков") +
  theme(axis.text.x = element_text(angle = 45, vjust = 0.5))
# Out:
# plot without title

# %%
most_popular_genre <- data %>%
  count(music_genre) %>%
  filter(n == max(n)) %>%
  pull(music_genre)
cat(paste("Most popular genre is", most_popular_genre, "\n"))
# Out:
# Most popular genre is Electronic

# %%
danceability_by_genre <- data %>% 
  group_by(music_genre) %>% 
  summarize(mean_danceability = mean(danceability))

most_danceable_genre <- danceability_by_genre %>% 
  arrange(desc(mean_danceability)) %>% 
  head(1)

cat("Самый танцевальный жанр:", most_danceable_genre$music_genre, "\n")
cat("Среднее значение показателя danceability:", most_danceable_genre$mean_danceability, "\n")
# Out:
# Самый танцевальный жанр: Hip-Hop
# Среднее значение показателя danceability: 0.7190493

# %%
tonality_by_genre <- data %>%
  group_by(music_genre, key) %>%
  summarise(track_count = n()) %>%
  mutate(mode = ifelse(sum(key == "C") == 0 & sum(key == "D") == 0, "No tracks",
                       ifelse(track_count[key == "C"] < track_count[key == "D"], "major", "minor")))

ggplot(tonality_by_genre, aes(x = music_genre, y = track_count, fill = mode)) +
  geom_bar(stat = "identity") +
  labs(title = "Dominant tonality by genre", 
       x = "Genres", y = "Track count") +
  scale_fill_manual(values = c("#377eb8", "#e41a1c", "#999999"), 
                    labels = c("major", "minor", "No tracks")) +
  theme(axis.text.x = element_text(angle = 45, vjust = 0.5))
# Out:
# `summarise()` has grouped output by 'music_genre'. You can override using the
# `.groups` argument.
# plot without title

# %% [markdown]
# Задание №3

# %% [markdown]
# 1. Выведите исполнителя, у которого больше всего треков в датасете. И того, у которого их меньше всех.
# 2. Покажите на горизонтральной столбиковой диаграмме топ-20 исполнителей. Изучите результат и сделайте выводы.

# %%
# Исполнитель с наибольшим количеством треков
most_tracks <- names(sort(table(data$artist_name), decreasing = TRUE)[1])
most_count <- max(table(data$artist_name))
cat("Исполнитель с наибольшим количеством треков:", most_tracks, "(", most_count, "треков)\n")

# Исполнитель с наименьшим количеством треков
least_tracks <- names(sort(table(data$artist_name))[1])
least_count <- min(table(data$artist_name))
cat("Исполнитель с наименьшим количеством треков:", least_tracks, "(", least_count, "трек)\n")
# Out:
# Исполнитель с наибольшим количеством треков: Nobuo Uematsu ( 142 треков)
# Исполнитель с наименьшим количеством треков: "Weird Al" Yankovic ( 1 трек)

# %%
library(ggplot2)

top_artists <- data %>%
  group_by(artist_name) %>%
  summarize(total_songs = n()) %>%
  top_n(20, total_songs) %>%
  arrange(desc(total_songs))

ggplot(top_artists, aes(y = reorder(artist_name, -total_songs), x = total_songs)) +
  geom_bar(stat = "identity", fill = "steelblue") +
  theme(axis.text.y = element_text(hjust = 1)) +
  ggtitle("Топ-20 исполнителей по количеству треков") +
  xlab("Количество треков") +
  ylab("Исполнитель")
# Out:
# plot without title

# %% [markdown]
# Задание №4

# %% [markdown]
# 1. Постройте корреляционную матрицу для характеристик треков. Между какими характеристиками сильная корреляция? Между какими слабая?
# 2. Есть ли характеристики, между которыми корреляции практически нет.
# Посчитайте корреляцию между популярностью (popularity) и длиной названия трека.

# %%
install.packages("corrplot")
library(corrplot)
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# corrplot 0.92 loaded

# %%
install.packages("palmerpenguins")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
data$tempo <- as.numeric(data$tempo)
# Out:
# Warning message in eval(expr, envir, enclos):
# “NAs introduced by coercion”

# %%
library(corrplot)
library(RColorBrewer)

# Remove missing values and convert tempo to numeric
data_clean <- na.omit(data[c('duration_ms', 'loudness', 'tempo', 'danceability', 'energy')])
data_clean$tempo <- as.numeric(data_clean$tempo)

# Calculate correlation matrix
cor_mat <- cor(data_clean)

# Create color ramp and plot correlation matrix
col_ramp <- colorRampPalette(brewer.pal(11, 'PiYG'))
corrplot(cor_mat, method = "color", tl.pos = "d", addCoef.col = "black", col = col_ramp(100))
# Out:
# Plot with title “”

# %%
cor(data$popularity, nchar(data$track_name))
# Out:
# [1] -0.2245376

# %% [markdown]
# Задание №5

# %% [markdown]
# Покажите на ящиковой диаграмме отношение популярности треков к жанру. Какие жанры похожи между собой?

# %%
library(ggplot2)

ggplot(data, aes(x = music_genre, y = popularity)) +
  geom_boxplot(fill = "steelblue") +
  ggtitle("Отношение популярности треков к жанру") +
  xlab("Жанр") +
  ylab("Популярность")
# Out:
# plot without title

# %% [markdown]
# Задание №7

# %% [markdown]
# На вертикальной столбиковой диаграмме для самого популярного (popularity) и самого непопулярного жанров покажите средние значения по всем характеристикам. Отрицательные и положительные значения характеристик показывайте разными цветами.

# %%
data <- na.omit(data)

# %%
non_numeric_cols <- c("instance_id", "artist_name", "track_name")
numeric_cols <- setdiff(colnames(data), non_numeric_cols)

for (col in numeric_cols) {
  data[[col]] <- as.numeric(gsub("[^0-9.]", "", data[[col]]))
}

# %%
non_numeric_cols <- c("artist_name", "track_name")
numeric_cols <- setdiff(names(data), non_numeric_cols)

data[, numeric_cols] <- apply(data[, numeric_cols], 2, as.numeric)

# %%
data$acousticness <- as.numeric(data$acousticness)
data$danceability <- as.numeric(data$danceability)
data$energy <- as.numeric(data$energy)
data$instrumentalness <- as.numeric(data$instrumentalness)
data$liveness <- as.numeric(data$liveness)
data$speechiness <- as.numeric(data$speechiness)
data$valence <- as.numeric(data$valence)

# %%
install.packages("dplyr")
install.packages("ggplot2")
install.packages("gridExtra")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
library(dplyr)
library(ggplot2)

popular_genres <- data %>% 
  group_by(music_genre) %>% 
  summarize_all(mean) %>% 
  arrange(desc(popularity)) %>% 
  slice(1)

unpopular_genres <- data %>% 
  group_by(music_genre) %>% 
  summarize_all(mean) %>% 
  arrange(desc(popularity)) %>% 
  slice_tail(n = 1)

characteristics <- c('acousticness', 'danceability', 'energy', 'instrumentalness', 'liveness', 'loudness', 'speechiness', 'valence')

popular_means <- popular_genres[, characteristics] %>% 
  unlist() %>% 
  as.numeric()

popular_colors <- ifelse(popular_means < 0, 'red', ifelse(popular_means == 0, 'grey', 'green'))

popular_plot <- ggplot(data.frame(characteristics, popular_means), aes(x=characteristics, y=popular_means, fill=popular_colors)) +
  geom_bar(stat='identity') + 
  scale_fill_manual(values=popular_colors) +
  ggtitle(paste("Средние значения для популярного жанра (", popular_genres$music_genre, ")", sep="")) + 
  ylim(-1, 1) +
  xlab('Характеристика') + 
  ylab('Среднее значение') + 
  theme_minimal() + 
  theme(plot.title = element_text(hjust = 0.5))

unpopular_means <- unpopular_genres[, characteristics] %>% 
  unlist() %>% 
  as.numeric()

unpopular_colors <- ifelse(unpopular_means < 0, 'red', ifelse(unpopular_means == 0, 'grey', 'green'))

unpopular_plot <- ggplot(data.frame(characteristics, unpopular_means), aes(x=characteristics, y=unpopular_means, fill=unpopular_colors)) +
  geom_bar(stat='identity') + 
  scale_fill_manual(values=unpopular_colors) +
  ggtitle(paste("Средние значения для непопулярного жанра (", unpopular_genres$music_genre, ")", sep="")) + 
  ylim(-1, 1) +
  xlab('Характеристика') + 
  ylab('Среднее значение') + 
  theme_minimal() + 
  theme(plot.title = element_text(hjust = 0.5))

gridExtra::grid.arrange(popular_plot, unpopular_plot, ncol=1)
# Out:
# Warning message:
# “There were 2 warnings in `summarise()`.
# The first warning was:
# ℹ In argument: `artist_name = (function (x, ...) ...`.
# ℹ In group 1: `music_genre = NA`.
# Caused by warning in `mean.default()`:
# ! argument is not numeric or logical: returning NA
# ℹ Run `dplyr::last_dplyr_warnings()` to see the 1 remaining warning.”
# Warning message:
# “There were 2 warnings in `summarise()`.
# The first warning was:
# ℹ In argument: `artist_name = (function (x, ...) ...`.
# ℹ In group 1: `music_genre = NA`.
# Caused by warning in `mean.default()`:
# ! argument is not numeric or logical: returning NA
# ℹ Run `dplyr::last_dplyr_warnings()` to see the 1 remaining warning.”
# Warning message:
# “Removed 2 rows containing missing values (`position_stack()`).”
# Warning message:
# “Removed 2 rows containing missing values (`position_stack()`).”
# plot without title

# %% [markdown]
# Задание №8

# %% [markdown]
# 1. Добавьте в данные категориальный столбец длительность_трека, в котором будут значения: "короткая" (<=3min), "средняя" (>3min, <=5min), "длинная" (>5min).
# 2. Покажите график плотности распределения данных в столбце loudness, сгруппированных по категориям длительности.
# 3. На круговой диаграмме покажите численное соотношение треков разной длительности.

# %%
install.packages("plotly")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘Rcpp’, ‘later’, ‘htmlwidgets’, ‘lazyeval’, ‘crosstalk’, ‘promises’

# %%
install.packages("ggplot2")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
library(dplyr)
library(ggplot2)

data <- data %>%
  mutate(dur_category = cut(duration_ms/60000, 
                             breaks = c(0, 3, 5, Inf), 
                             labels = c("короткая", "средняя", "длинная")))

ggplot(data, aes(x = loudness, fill = dur_category)) +
  geom_density(alpha = 0.5) +
  xlab("Loudness") +
  ylab("Density") +
  ggtitle("Распределение данных в столбце loudness, сгруппированных по категориям длительности")
# Out:
# plot without title

# %%
ggplot(data, aes(x = "", fill = dur_category)) +
  geom_bar(width = 1) +
  coord_polar(theta = "y") +
  labs(fill = "Длительность трека") +
  ggtitle("Численное соотношение треков разной длительности")
# Out:
# plot without title
